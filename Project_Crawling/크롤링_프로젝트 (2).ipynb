# %%
from bs4 import BeautifulSoup as bs
import requests
import json

# %%
resp = requests.get("https://www.yanolja.com/search/%EC%A0%9C%EC%A3%BC%EB%8F%84?placeListType=search&keyword=%EC%A0%9C%EC%A3%BC%EB%8F%84")     ## 위의 코드와 같은 코드
resp
# Out:
# <Response [200]>

# %%
url = "https://www.yanolja.com/search/%EC%A0%9C%EC%A3%BC%EB%8F%84"
params = {
    'placeListType' : 'search',
    'keyword' : '제주도',
}

resp = requests.get(url, params = params)
resp
# Out:
# <Response [200]>

# %%
# '제주도' 인코딩 문제를 먼저 해결해야한다!!

import urllib
urllib.parse.quote('https://www.yanolja.com/search/제주도?placeListType=search&keyword=제주도')
# Out:
# 'https%3A//www.yanolja.com/search/%EC%A0%9C%EC%A3%BC%EB%8F%84%3FplaceListType%3Dsearch%26keyword%3D%EC%A0%9C%EC%A3%BC%EB%8F%84'

# %%
base_url = "https://www.yanolja.com/api/v1/contents/search"
params = {
    'capacityAdult': 1,
    'capacityChild': 0,
    'page': 1,
    'limit': 20,
    'keyword': '제주도',
    'checkinDate': '2020-08-16',
    'checkoutDate': '2020-08-17',
    'searchKeyword': '제주도',
    'advert': 'KEYWORD',
    'searchType': 'all',
    'all': 1,
    'sort': 100,
    'themes': None,
    'lat': '37.50681',
    'lng': '127.06624',
    'capacityChildAges': None  
}

headers = {
    'Referer' : 'https://www.yanolja.com/search/{0}?placeListType=search&keyword={0}'.format(urllib.parse.quote('제주도')),
    'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'Cookie': 'ACEUCI=1; %2Fsearch%2F%EC%A0%9C%EC%A3%BC%EB%8F%84%2Fkeyword-all={%22keyword%22:%22%EC%A0%9C%EC%A3%BC%EB%8F%84%22%2C%22searchKeyword%22:%22%EC%A0%9C%EC%A3%BC%EB%8F%84%22%2C%22checkinDate%22:%222020-08-16%22%2C%22checkoutDate%22:%222020-08-17%22%2C%22capacityAdult%22:1%2C%22capacityChild%22:0%2C%22capacityChildAges%22:%22%22}; cgntId=ap-northeast-2%3A2b47caae-3694-44f0-9d2b-43c98b30c098; yanolja_sid=s%3A0K-pijLPMujuW6NI5cJVcGOYBO2FXY0h.ZwiC623ThkJsrpFM9m7MiLj%2F8qYFHr3272Xla0K8NCk; SavedFiltersKey=/search/%EC%A0%9C%EC%A3%BC%EB%8F%84/keyword-all; ACEUACS=1596521299174217533; ACEFCID=UID-5F28FB542D0B4D05779333B5; _fbp=fb.1.1596521300441.1991528559; _ga=GA1.2.1408952294.1596521300; _gid=GA1.2.788840749.1596521300; location={%22latitude%22:%2237.50681%22%2C%22longitude%22:%22127.06624%22%2C%22address%22:%22%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EA%B0%95%EB%82%A8%EA%B5%AC%20%ED%85%8C%ED%97%A4%EB%9E%80%EB%A1%9C108%EA%B8%B8%2042%22%2C%22addressShort%22:%22%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EA%B0%95%EB%82%A8%EA%B5%AC%20%ED%85%8C%ED%97%A4%EB%9E%80%EB%A1%9C108%EA%B8%B8%22%2C%22addressOnlyRoad%22:%22%ED%85%8C%ED%97%A4%EB%9E%80%EB%A1%9C108%EA%B8%B8%22}; wcs_bt=ae93a192ec48a4:1596521393; AWSALB=zm/Jfq0CVy83/Q/bcMcY2ADivgyVdh6KNQc6bG1tPs9SA7T5733p2wvOClRpxNMSodWkruizJEGIcJbThOG1sBYm+WURo+8cqojOGppWN4ykkwQMNbQuiwexg5Nx; AWSALBCORS=zm/Jfq0CVy83/Q/bcMcY2ADivgyVdh6KNQc6bG1tPs9SA7T5733p2wvOClRpxNMSodWkruizJEGIcJbThOG1sBYm+WURo+8cqojOGppWN4ykkwQMNbQuiwexg5Nx'
}

## 호텔리스트가 홈페이지랑 다르게 나옴 -> 쿠키가 계속 갱신되는 것을 방지하기 위해 -> 처음 홈페이지에 들어가자마자의 쿠키를 저장해놓는다.
s = requests.Session()
s.get("https://www.yanolja.com/search/제주도?placeListType=search&keyword=제주도")
resp = s.get(base_url, params=params, headers=headers)
# resp = requests.get(base_url, params = params, headers=headers)
resp
# Out:
# <Response [200]>

# %%
item_li = json.loads(resp.text)
item_li
# Out:
# {'paging': {'isLast': False, 'current': 1, 'total': 96},
#  'adverts': {'counts': 0, 'totalCounts': None, 'lists': []},
#  'subAdverts': {'counts': 0, 'totalCounts': None, 'lists': []},
#  'motels': {'counts': 20,
#   'totalCounts': 1916,
#   'lists': [{'key': '3013869',
#     'association': '1',
#     'gradeInfo': None,
#     'thumb': 'https://yaimg.yanolja.com/v5/2019/11/26/15/1280/5ddcccde7503a3.01643407.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '제주 해피니스펜션 (오션뷰,18.3월신축)',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.6',
#     'reviewStar': '4.6',
#     'reviewCounts': '149',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 제주시 조천읍 와흘리 1141-1 ',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.497702',
#     'lng': '126.6362496',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '3',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '숙박',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '예약가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '59,000원',
#       'price': '160,000원',
#       'rawDiscountPrice': 59000,
#       'rawPrice': 160000,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': 63,
#       'discountRateModifier': '%~'}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '2',
#     'cardType': 'SPECIAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '제주 해피니스펜션 (오션뷰,18.3월신축)',
#     'distance': '446.5km',
#     'rawDistance': 446516},
#    {'key': '3014838',
#     'association': '1',
#     'gradeInfo': {'authenticate': {'type': 'JTA'}, 'title': '4성급'},
#     'thumb': 'https://yaimg.yanolja.com/v5/2020/06/15/10/1280/5ee6ce6ba636f7.09567610.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '호텔 시리우스 제주',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.6',
#     'reviewStar': '4.6',
#     'reviewCounts': '680',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 제주시 연동 2334-4',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.493399',
#     'lng': '126.490957',
#     'reserveType': '1',
#     'event': 'Y',
#     'contentsType': '2',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': ['★제주 공항 근처 추천 호텔★'],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '1',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '호텔', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '제주국제공항 차량 10분',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '현장결제가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '242,000원',
#       'price': '',
#       'rawDiscountPrice': 242000,
#       'rawPrice': 0,
#       'priceNote': '예약마감',
#       'priceNoteForWalkin': None,
#       'discountRate': None,
#       'discountRateModifier': ''}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '2',
#     'cardType': 'SPECIAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '호텔 시리우스 제주',
#     'distance': '448.3km',
#     'rawDistance': 448333},
#    {'key': '3008356',
#     'association': '1',
#     'gradeInfo': None,
#     'thumb': 'https://yaimg.yanolja.com/v5/2019/03/12/17/1280/5c877200985842.75402885.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '서귀포 수펜션',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.8',
#     'reviewStar': '4.8',
#     'reviewCounts': '51',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 서귀포시 안덕면 창천리 967-1 ',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.2414562',
#     'lng': '126.3670064',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '3',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '1',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '자체픽업 가능', 'postfix': None},
#     'locationDesc': '',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '현장결제가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '100,000원',
#       'price': '',
#       'rawDiscountPrice': 100000,
#       'rawPrice': 0,
#       'priceNote': '예약마감',
#       'priceNoteForWalkin': None,
#       'discountRate': None,
#       'discountRateModifier': ''}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '서귀포 수펜션',
#     'distance': '477.4km',
#     'rawDistance': 477473},
#    {'key': '3010287',
#     'association': '1',
#     'gradeInfo': {'authenticate': {'type': 'HN'}, 'title': '4성급'},
#     'thumb': 'https://yaimg.yanolja.com/v5/2020/07/31/17/1280/5f23d3501d3583.51122211.jpg',
#     'modifiers': {'hotDealLv1': None,
#      'coupon': {'title': '선착순', 'desc': '1만원'},
#      'recommend': None},
#     'name': '유탑유블레스호텔 제주함덕',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.6',
#     'reviewStar': '4.6',
#     'reviewCounts': '469',
#     'ownerReplyCount': '189',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 제주시 조천읍 함덕리 1269-9 유탑유블레스호텔',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.542329',
#     'lng': '126.666165',
#     'reserveType': '1',
#     'event': 'Y',
#     'contentsType': '2',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': ['★전 투숙객 체크인 시 웰컴드링크 2잔 제공★'],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '호텔', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '함덕해수욕장 바로 앞',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '당일특가',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '당일특가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '89,000원',
#       'price': '300,000원',
#       'rawDiscountPrice': 89000,
#       'rawPrice': 300000,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': 70,
#       'discountRateModifier': '%~'}],
#     'availableCoupon': True,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [{'status': None, 'desc': '1만원 즉시할인'}],
#     'title': '유탑유블레스호텔 제주함덕',
#     'distance': '441.3km',
#     'rawDistance': 441353},
#    {'key': '3002004',
#     'association': '1',
#     'gradeInfo': {'authenticate': {'type': 'HN'}, 'title': '가족호텔'},
#     'thumb': 'https://yaimg.yanolja.com/v5/2019/10/21/11/1280/5dad18bd937ac4.75020554.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': 'HY 초이호스텔 제주',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.4',
#     'reviewStar': '4.4',
#     'reviewCounts': '74',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 서귀포시 서귀동 316-14',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.247066',
#     'lng': '126.558454',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '2',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '가족호텔', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '이중섭거리 도보 5분',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '숙박',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '예약가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '40,000원',
#       'price': '',
#       'rawDiscountPrice': 40000,
#       'rawPrice': 0,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': None,
#       'discountRateModifier': ''}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': 'HY 초이호스텔 제주',
#     'distance': '474.8km',
#     'rawDistance': 474853},
#    {'key': '3001618',
#     'association': '1',
#     'gradeInfo': {'authenticate': {'type': 'HN'}, 'title': '비즈니스'},
#     'thumb': 'https://yaimg.yanolja.com/v5/2020/07/23/16/1280/5f1943442d8558.71550878.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '호텔 리젠트마린',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.6',
#     'reviewStar': '4.6',
#     'reviewCounts': '923',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 제주시 건입동 1443 호텔리젠트마린더블루',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.517623',
#     'lng': '126.52711',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '2',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '비즈니스', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '제주국제공항 자동차 15분',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '숙박특가',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '예약가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '106,400원',
#       'price': '242,000원',
#       'rawDiscountPrice': 106400,
#       'rawPrice': 242000,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': 56,
#       'discountRateModifier': '%~'}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '호텔 리젠트마린',
#     'distance': '445.2km',
#     'rawDistance': 445292},
#    {'key': '3016229',
#     'association': '1',
#     'gradeInfo': None,
#     'thumb': 'https://yaimg.yanolja.com/v5/2020/04/17/17/1280/5e996cda536904.64178035.jpg',
#     'modifiers': {'hotDealLv1': None,
#      'coupon': {'title': '선착순', 'desc': '7천원 마감임박'},
#      'recommend': None},
#     'name': '제주 빈티지1950카페펜션(조식제공)',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.8',
#     'reviewStar': '4.8',
#     'reviewCounts': '290',
#     'ownerReplyCount': '247',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 제주시 구좌읍 덕행로 175-48 ',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.53116077442166',
#     'lng': '126.79639853793742',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '3',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '자체픽업 가능', 'postfix': None},
#     'locationDesc': '',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '숙박특가',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '예약가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '129,000원',
#       'price': '220,000원',
#       'rawDiscountPrice': 129000,
#       'rawPrice': 220000,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': 41,
#       'discountRateModifier': '%~'}],
#     'availableCoupon': True,
#     'hotDealLv1': False,
#     'partnershipType': '2',
#     'cardType': 'SPECIAL',
#     'couponInfo': None,
#     'usableCoupons': [{'status': '마감임박', 'desc': '7천원 즉시할인'}],
#     'title': '제주 빈티지1950카페펜션(조식제공)',
#     'distance': '441.7km',
#     'rawDistance': 441777},
#    {'key': '3004676',
#     'association': '1',
#     'gradeInfo': None,
#     'thumb': 'https://yaimg.yanolja.com/v5/2020/05/14/16/1280/5ebcf785164bc9.13381662.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '서귀포 펜션연리',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '5',
#     'reviewStar': '5',
#     'reviewCounts': '37',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 서귀포시 하예동 463-1 ',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.2403614107',
#     'lng': '126.3863071234',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '3',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '숙박',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '예약가',
#       'extraInfo': '16:00 ~',
#       'discountPrice': '98,000원',
#       'price': '',
#       'rawDiscountPrice': 98000,
#       'rawPrice': 0,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': None,
#       'discountRateModifier': ''}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '서귀포 펜션연리',
#     'distance': '477.3km',
#     'rawDistance': 477363},
#    {'key': '26526',
#     'association': '1',
#     'gradeInfo': None,
#     'thumb': 'https://yaimg.yanolja.com/resize/place/v4/2017/08/18/17/1280/5996a2bc8cdb75.24977947.jpg',
#     'modifiers': {'hotDealLv1': {'title': '핫딜', 'desc': '10%'},
#      'coupon': {'title': '선착순', 'desc': '5천원'},
#      'recommend': None},
#     'name': '제주 컬리넌 호텔',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.4',
#     'reviewStar': '4.4',
#     'reviewCounts': '1212',
#     'ownerReplyCount': '965',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 제주시 연동 284-54',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '1',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.4853023',
#     'lng': '126.4928633',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '1',
#     'associateLevel': '0',
#     'bestPrice': '1',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '이미지와 배정된 객실은 인테리어가 상이할 수 있습니다',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': True,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '연동사거리 도보 5분 이내',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '',
#       'label': '대실',
#       'note': '숙소에 문의',
#       'badgeTitle': '현장결제가',
#       'extraInfo': '',
#       'discountPrice': '',
#       'price': '',
#       'rawDiscountPrice': 0,
#       'rawPrice': 0,
#       'priceNote': '예약마감',
#       'priceNoteForWalkin': '숙소에 문의',
#       'discountRate': None,
#       'discountRateModifier': ''},
#      {'badgeColorIndex': '1',
#       'badgeText': '숙박특가',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '예약가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '49,500원',
#       'price': '160,000원',
#       'rawDiscountPrice': 49500,
#       'rawPrice': 160000,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': 69,
#       'discountRateModifier': '%~'}],
#     'availableCoupon': True,
#     'hotDealLv1': True,
#     'partnershipType': '3',
#     'cardType': 'BEST',
#     'couponInfo': None,
#     'usableCoupons': [{'status': None, 'desc': '5천원 즉시할인'}],
#     'title': '제주 컬리넌 호텔',
#     'distance': '449.2km',
#     'rawDistance': 449205},
#    {'key': '3009684',
#     'association': '1',
#     'gradeInfo': None,
#     'thumb': 'https://yaimg.yanolja.com/v5/2018/10/24/01/1280/5bcf52d452b819.89005820.png',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '서귀포 라운지하우스제주다펜션',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '5',
#     'reviewStar': '5',
#     'reviewCounts': '2',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 서귀포시 안덕면 사계리 3537-1 ',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.2231844201',
#     'lng': '126.2926958474',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '3',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '숙박',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '예약가',
#       'extraInfo': '17:00 ~',
#       'discountPrice': '65,000원',
#       'price': '',
#       'rawDiscountPrice': 65000,
#       'rawPrice': 0,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': None,
#       'discountRateModifier': ''}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '서귀포 라운지하우스제주다펜션',
#     'distance': '480.4km',
#     'rawDistance': 480423},
#    {'key': '3009313',
#     'association': '1',
#     'gradeInfo': {'authenticate': {'type': 'HN'}, 'title': '4성급'},
#     'thumb': 'https://yaimg.yanolja.com/v5/2020/07/22/17/1280/5f17f6395465b2.93115486.jpg',
#     'modifiers': {'hotDealLv1': None,
#      'coupon': {'title': '선착순', 'desc': '3천원'},
#      'recommend': None},
#     'name': '아트스테이 서귀포 하버',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.6',
#     'reviewStar': '4.6',
#     'reviewCounts': '2063',
#     'ownerReplyCount': '1199',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 서귀포시 서귀동 162-1 하워드존슨호텔 제주 서귀포 하버',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.24559',
#     'lng': '126.566701',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '2',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '호텔', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '서귀포 이중섭문화거리',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '당일특가',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '당일특가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '51,000원',
#       'price': '220,000원',
#       'rawDiscountPrice': 51000,
#       'rawPrice': 220000,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': 76,
#       'discountRateModifier': '%~'}],
#     'availableCoupon': True,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [{'status': None, 'desc': '3천원 즉시할인'}],
#     'title': '아트스테이 서귀포 하버',
#     'distance': '474.9km',
#     'rawDistance': 474944},
#    {'key': '3000833',
#     'association': '1',
#     'gradeInfo': {'authenticate': {'type': 'JTA'}, 'title': '4성급'},
#     'thumb': 'https://yaimg.yanolja.com/v5/2020/07/06/18/1280/5f02f1dcc18038.64220035.jpg',
#     'modifiers': {'hotDealLv1': None,
#      'coupon': {'title': '선착순', 'desc': '3천원'},
#      'recommend': None},
#     'name': '빠레브 호텔 제주',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.5',
#     'reviewStar': '4.5',
#     'reviewCounts': '290',
#     'ownerReplyCount': '283',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 서귀포시 강정동 173 호텔빠레브',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.252734',
#     'lng': '126.506701',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '2',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '호텔', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '서귀포시 강정동',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '숙박',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '예약가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '51,030원',
#       'price': '295,000원',
#       'rawDiscountPrice': 51030,
#       'rawPrice': 295000,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': 82,
#       'discountRateModifier': '%~'}],
#     'availableCoupon': True,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [{'status': None, 'desc': '3천원 즉시할인'}],
#     'title': '빠레브 호텔 제주',
#     'distance': '474.7km',
#     'rawDistance': 474707},
#    {'key': '3000838',
#     'association': '1',
#     'gradeInfo': {'authenticate': {'type': 'JTA'}, 'title': '5성급'},
#     'thumb': 'https://yaimg.yanolja.com/v5/2020/07/21/13/1280/5f167466a83453.68322211.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '라마다 프라자 제주',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.7',
#     'reviewStar': '4.7',
#     'reviewCounts': '177',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 제주시 삼도이동 1254 라마다프라자호텔',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.518592',
#     'lng': '126.517502',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '2',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '호텔', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '제주국제공항 약 3km',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '당일특가',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '당일특가',
#       'extraInfo': '14:00 ~',
#       'discountPrice': '189,992원',
#       'price': '411,400원',
#       'rawDiscountPrice': 189992,
#       'rawPrice': 411400,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': 53,
#       'discountRateModifier': '%~'}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '라마다 프라자 제주',
#     'distance': '445.2km',
#     'rawDistance': 445282},
#    {'key': '3001285',
#     'association': '1',
#     'gradeInfo': {'authenticate': {'type': 'HN'}, 'title': '가족호텔'},
#     'thumb': 'https://yaimg.yanolja.com/v5/2020/05/21/14/1280/5ec614d455b428.36647174.jpg',
#     'modifiers': {'hotDealLv1': None,
#      'coupon': {'title': '선착순', 'desc': '3천원'},
#      'recommend': None},
#     'name': '봄그리고가을 호텔&리조트',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.6',
#     'reviewStar': '4.6',
#     'reviewCounts': '1099',
#     'ownerReplyCount': '822',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 서귀포시 성산읍 시흥리 산208 봄그리고가을리조트',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.474087',
#     'lng': '126.911098',
#     'reserveType': '1',
#     'event': 'Y',
#     'contentsType': '2',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': ['★야놀자 단독특가-야외수영장 OPEN★'],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '가족호텔', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '성산일출봉 3km',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '당일특가',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '당일특가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '73,000원',
#       'price': '200,000원',
#       'rawDiscountPrice': 73000,
#       'rawPrice': 200000,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': 63,
#       'discountRateModifier': '%~'}],
#     'availableCoupon': True,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [{'status': None, 'desc': '3천원 즉시할인'}],
#     'title': '봄그리고가을 호텔&리조트',
#     'distance': '447.6km',
#     'rawDistance': 447651},
#    {'key': '1000086997',
#     'association': '1',
#     'gradeInfo': None,
#     'thumb': 'https://yaimg.yanolja.com/v5/2019/09/03/19/1280/5d6e3a15103364.59735184.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '제주 29풀빌라',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.4',
#     'reviewStar': '4.4',
#     'reviewCounts': '9',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 제주시 애월읍 곽지리 378-1 ',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.43272345160262',
#     'lng': '126.32165976755651',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '3',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '숙박',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '예약가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '250,000원',
#       'price': '',
#       'rawDiscountPrice': 250000,
#       'rawPrice': 0,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': None,
#       'discountRateModifier': ''}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '제주 29풀빌라',
#     'distance': '457km',
#     'rawDistance': 457036},
#    {'key': '3017077',
#     'association': '1',
#     'gradeInfo': None,
#     'thumb': 'https://yaimg.yanolja.com/v5/2018/12/04/17/1280/5c0634fd038f49.51790746.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '제주 늘하우스 펜션&게스트하우스',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '5',
#     'reviewStar': '5',
#     'reviewCounts': '1',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 서귀포시 남원읍 신흥리 176-4',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.3006995',
#     'lng': '126.7660081',
#     'reserveType': '1',
#     'event': 'Y',
#     'contentsType': '4',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': ['서귀포시 남원 가족형, 연인형, 바베큐, 감귤체험'],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '흥산 초등학교',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '숙박특가',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '예약가',
#       'extraInfo': '16:00 ~',
#       'discountPrice': '15,000원',
#       'price': '20,000원',
#       'rawDiscountPrice': 15000,
#       'rawPrice': 20000,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': 25,
#       'discountRateModifier': '%~'}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '제주 늘하우스 펜션&게스트하우스',
#     'distance': '467.4km',
#     'rawDistance': 467456},
#    {'key': '3000997',
#     'association': '1',
#     'gradeInfo': {'authenticate': {'type': 'JTA'}, 'title': '4성급'},
#     'thumb': 'https://yaimg.yanolja.com/v5/2020/07/23/16/1280/5f193bc46926a4.25610109.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '롯데 시티호텔 제주',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.8',
#     'reviewStar': '4.8',
#     'reviewCounts': '365',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 제주시 연동 2324-6 제주연동 롯데시티호텔',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.490785',
#     'lng': '126.48661',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '2',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '호텔', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '제주국제공항 자동차 5분',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '숙박특가',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '예약가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '166,610원',
#       'price': '374,000원',
#       'rawDiscountPrice': 166610,
#       'rawPrice': 374000,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': 55,
#       'discountRateModifier': '%~'}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '롯데 시티호텔 제주',
#     'distance': '448.6km',
#     'rawDistance': 448667},
#    {'key': '3012459',
#     'association': '1',
#     'gradeInfo': None,
#     'thumb': 'https://yaimg.yanolja.com/v5/2018/07/13/10/1280/5b47ffcdbb7ea1.55648734.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '제주 그래펜션',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '5',
#     'reviewStar': '5',
#     'reviewCounts': '8',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 제주시 구좌읍 행원리 2344 ',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.5334797',
#     'lng': '126.7952051',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '3',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '1',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '자체픽업 가능', 'postfix': None},
#     'locationDesc': '',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '현장결제가',
#       'extraInfo': '16:00 ~',
#       'discountPrice': '120,000원',
#       'price': '',
#       'rawDiscountPrice': 120000,
#       'rawPrice': 0,
#       'priceNote': '예약마감',
#       'priceNoteForWalkin': None,
#       'discountRate': None,
#       'discountRateModifier': ''}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '제주 그래펜션',
#     'distance': '441.5km',
#     'rawDistance': 441526},
#    {'key': '3004672',
#     'association': '1',
#     'gradeInfo': None,
#     'thumb': 'https://yaimg.yanolja.com/v5/2020/07/30/12/1280/5f2243de937a56.61435654.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '제주 허브인휴양펜션',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '5',
#     'reviewStar': '5',
#     'reviewCounts': '28',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 제주시 한림읍 귀덕리 2731 ',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.4357194',
#     'lng': '126.290195',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '3',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '0',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '숙박',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '예약가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '90,600원',
#       'price': '330,000원',
#       'rawDiscountPrice': 90600,
#       'rawPrice': 330000,
#       'priceNote': None,
#       'priceNoteForWalkin': None,
#       'discountRate': 72,
#       'discountRateModifier': '%~'}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '4',
#     'cardType': 'NORMAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '제주 허브인휴양펜션',
#     'distance': '457.1km',
#     'rawDistance': 457138},
#    {'key': '1000104384',
#     'association': '1',
#     'gradeInfo': {'authenticate': {'type': 'HN'}, 'title': '가족호텔'},
#     'thumb': 'https://yaimg.yanolja.com/v5/2020/06/24/18/1280/5ef31e6fcecc45.18687518.jpg',
#     'modifiers': {'hotDealLv1': None, 'coupon': None, 'recommend': None},
#     'name': '에코그린 리조트&호텔&풀빌라',
#     'relation': '',
#     'franchise': '',
#     'reviewScore': '4.3',
#     'reviewStar': '4.3',
#     'reviewCounts': '112',
#     'ownerReplyCount': '0',
#     'hot': 'Y',
#     'addr1': '제주특별자치도 제주시 한림읍 귀덕리 1502',
#     'addr2': '',
#     'newIcon': 'N',
#     'authZoneType': '0',
#     'balloonZoneType': '0',
#     'myRoom': '0',
#     'myRoomType': '0',
#     'bestPick': '0',
#     'lat': '33.435929',
#     'lng': '126.291544',
#     'reserveType': '1',
#     'event': 'N',
#     'contentsType': '2',
#     'associateLevel': '0',
#     'bestPrice': '0',
#     'mildWild': '0',
#     'eventTitles': [],
#     'shortNotice': '',
#     'rentSoldout': '1',
#     'staySoldout': '1',
#     'daysSoldout': '0',
#     'todayCancel': '0',
#     'construct': '0',
#     'isMyRoom': False,
#     'iot': '0',
#     'luckyBox': '0',
#     'hotelGrade': {'prefix': None, 'title': '가족호텔', 'postfix': None},
#     'hotDeal': False,
#     'pickup': {'prefix': None, 'title': '', 'postfix': None},
#     'locationDesc': '협재해수욕장 차량 약 8분거리',
#     'displayPrices': [{'badgeColorIndex': '1',
#       'badgeText': '',
#       'label': '숙박',
#       'note': '',
#       'badgeTitle': '현장결제가',
#       'extraInfo': '15:00 ~',
#       'discountPrice': '150,000원',
#       'price': '',
#       'rawDiscountPrice': 150000,
#       'rawPrice': 0,
#       'priceNote': '예약마감',
#       'priceNoteForWalkin': None,
#       'discountRate': None,
#       'discountRateModifier': ''}],
#     'availableCoupon': False,
#     'hotDealLv1': False,
#     'partnershipType': '2',
#     'cardType': 'SPECIAL',
#     'couponInfo': None,
#     'usableCoupons': [],
#     'title': '에코그린 리조트&호텔&풀빌라',
#     'distance': '457km',
#     'rawDistance': 457096}]},
#  'expMeta': {'expWidget': 'SRPCONTENTSLOCALSTAY',
#   'expChannel': 'CX',
#   'expSpecifier': 'ap-northeast-2:adfdbf07-2b2c-48fd-8e65-2062949711c8',
#   'expLabId': None,
#   'expGroup': 'SRPCONTENTSLOCALSTAY_B',
#   'expGroupNo': 95,
#   'expTimestamp': 1596528353931,
#   'expKindOfApi': 'EXTERNAL',
#   'expDynamicConfig': {'abTestKey': '1'},
#   'expCustomLogs': {},
#   'expElementOutputType': 'PLACE'}}

# %%
type(item_li)
# Out:
# dict

# %%
# 호텔 이름
name_list = []

for i in range(20):
    name = item_li['motels']['lists'][i]['name']
    name_list.append(name)
print(name_list)
# Out:
# ['제주 해피니스펜션 (오션뷰,18.3월신축)', '호텔 시리우스 제주', '서귀포 수펜션', '유탑유블레스호텔 제주함덕', 'HY 초이호스텔 제주', '호텔 리젠트마린', '제주 빈티지1950카페펜션(조식제공)', '서귀포 펜션연리', '제주 컬리넌 호텔', '서귀포 라운지하우스제주다펜션', '아트스테이 서귀포 하버', '빠레브 호텔 제주', '라마다 프라자 제주', '봄그리고가을 호텔&리조트', '제주 29풀빌라', '제주 늘하우스 펜션&게스트하우스', '롯데 시티호텔 제주', '제주 그래펜션', '제주 허브인휴양펜션', '에코그린 리조트&호텔&풀빌라']

# %%
# 호텔 점수
score_list = []

for i in range(20):
    score = item_li['motels']['lists'][i]['reviewScore']
    score_list.append(score)
print(score_list)
# Out:
# ['4.6', '4.6', '4.8', '4.6', '4.4', '4.6', '4.8', '5', '4.4', '5', '4.6', '4.5', '4.7', '4.6', '4.4', '5', '4.8', '5', '5', '4.3']

# %%
# 호텔 리뷰 개수
count_list = []

for i in range(20):
    count = item_li['motels']['lists'][i]['reviewCounts']
    count_list.append(count)
print(count_list)
# Out:
# ['149', '680', '51', '469', '74', '923', '290', '37', '1212', '2', '2063', '290', '177', '1099', '9', '1', '365', '8', '28', '112']

# %%
# 호텔 가격 => 예약마감 상관없이 다 뜬다.
price_list = []

for i in range(20):
    if len(item_li['motels']['lists'][i]['displayPrices']) == 1:
        price = item_li['motels']['lists'][i]['displayPrices'][0]['rawDiscountPrice']
        price_list.append(price)
    elif len(item_li['motels']['lists'][i]['displayPrices']) >= 2:
        for j in range(2):
            if item_li['motels']['lists'][i]['displayPrices'][j]['badgeText'] == '숙박특가':
                price = item_li['motels']['lists'][i]['displayPrices'][j]['rawDiscountPrice']
                price_list.append(price)
print(price_list)
# Out:
# [59000, 242000, 100000, 89000, 40000, 106400, 129000, 98000, 49500, 65000, 51000, 51030, 189992, 73000, 250000, 15000, 166610, 120000, 90600, 150000]

# %%
# 호텔 가격 = > 예약마감이면 예약마감이 뜬다.
price_list = []

for i in range(20):
    if len(item_li['motels']['lists'][i]['displayPrices']) == 1:
        if item_li['motels']['lists'][i]['displayPrices'][0]['priceNote'] == 'None':
            price = item_li['motels']['lists'][i]['displayPrices'][0]['priceNote']
            price_list.append(price)
            
        elif item_li['motels']['lists'][i]['displayPrices'][0]['priceNote'] == 'None':
            price = item_li['motels']['lists'][i]['displayPrices'][0]['rawDiscountPrice']
            price_list.append(price)
            
    elif len(item_li['motels']['lists'][i]['displayPrices']) >= 2:
        for j in range(2):
            if item_li['motels']['lists'][i]['displayPrices'][j]['badgeText'] == '숙박특가':
                if item_li['motels']['lists'][i]['displayPrices'][j]['priceNote'] != 'None':
                    price = item_li['motels']['lists'][i]['displayPrices'][j]['priceNote']
                    price_list.append(price)
                    
                elif item_li['motels']['lists'][i]['displayPrices'][0]['priceNote'] == 'None':
                    price = item_li['motels']['lists'][i]['displayPrices'][j]['rawDiscountPrice']
                    price_list.append(price)
print(price_list)
# Out:
# [None]

# %% [markdown]
# ## for문 완성

# %%
item_list = []
#name_list = []
#score_list = []
#price_list = []


for i in range(20):
    
    # 호텔 이름
    
    name = item_li['motels']['lists'][i]['name']
    #name_list.append(name)
#print(name_list)

        
    
    # 호텔 점수
    
    score = item_li['motels']['lists'][i]['reviewScore']
    #score_list.append(score)
#print(score_list)



    # 리뷰 개수
    
    count = item_li['motels']['lists'][i]['reviewCounts']
    #count_list.append(count)
#print(count_list)



    # 호텔 가격 = > 예약마감이면 예약마감이 뜬다.

    if len(item_li['motels']['lists'][i]['displayPrices']) == 1:
        if item_li['motels']['lists'][i]['displayPrices'][0]['priceNote'] == '예약마감':
            price = '예약마감'
            #price_list.append(price)
            
        else:
            price = item_li['motels']['lists'][i]['displayPrices'][0]['rawDiscountPrice']
            #price_list.append(price)
            
    elif len(item_li['motels']['lists'][i]['displayPrices']) >= 2:
        for j in range(2):
            if item_li['motels']['lists'][i]['displayPrices'][j]['badgeText'] == '숙박특가':
                if item_li['motels']['lists'][i]['displayPrices'][j]['priceNote'] == '예약마감':
                    price = '예약마감'
                    #price_list.append(price)
                    
                else:
                    price = item_li['motels']['lists'][i]['displayPrices'][j]['rawDiscountPrice']
                    #price_list.append(price)
#print(price_list)



    item_list.append({'name' : name, 
                      'score' : score,
                      'count' : count,
                      'price' : price})
print(item_list)
# Out:
# [{'name': '제주 해피니스펜션 (오션뷰,18.3월신축)', 'score': '4.6', 'count': '149', 'price': 59000}, {'name': '호텔 시리우스 제주', 'score': '4.6', 'count': '680', 'price': '예약마감'}, {'name': '서귀포 수펜션', 'score': '4.8', 'count': '51', 'price': '예약마감'}, {'name': '유탑유블레스호텔 제주함덕', 'score': '4.6', 'count': '469', 'price': 89000}, {'name': 'HY 초이호스텔 제주', 'score': '4.4', 'count': '74', 'price': 40000}, {'name': '호텔 리젠트마린', 'score': '4.6', 'count': '923', 'price': 106400}, {'name': '제주 빈티지1950카페펜션(조식제공)', 'score': '4.8', 'count': '290', 'price': 129000}, {'name': '서귀포 펜션연리', 'score': '5', 'count': '37', 'price': 98000}, {'name': '제주 컬리넌 호텔', 'score': '4.4', 'count': '1212', 'price': 49500}, {'name': '서귀포 라운지하우스제주다펜션', 'score': '5', 'count': '2', 'price': 65000}, {'name': '아트스테이 서귀포 하버', 'score': '4.6', 'count': '2063', 'price': 51000}, {'name': '빠레브 호텔 제주', 'score': '4.5', 'count': '290', 'price': 51030}, {'name': '라마다 프라자 제주', 'score': '4.7', 'count': '177', 'price': 189992}, {'name': '봄그리고가을 호텔&리조트', 'score': '4.6', 'count': '1099', 'price': 73000}, {'name': '제주 29풀빌라', 'score': '4.4', 'count': '9', 'price': 250000}, {'name': '제주 늘하우스 펜션&게스트하우스', 'score': '5', 'count': '1', 'price': 15000}, {'name': '롯데 시티호텔 제주', 'score': '4.8', 'count': '365', 'price': 166610}, {'name': '제주 그래펜션', 'score': '5', 'count': '8', 'price': '예약마감'}, {'name': '제주 허브인휴양펜션', 'score': '5', 'count': '28', 'price': 90600}, {'name': '에코그린 리조트&호텔&풀빌라', 'score': '4.3', 'count': '112', 'price': '예약마감'}]

# %%
item_table = dict(zip(name_list, score_list)
print(item_table)
# Out:
#   File "<ipython-input-4-2b7d61fb5030>", line 2
#     print(item_table)
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 함수 정의

# %%
from bs4 import BeautifulSoup
import requests
import json

def page_item_list(page):
    base_url = "https://www.yanolja.com/api/v1/contents/search"
    params = {
        'capacityAdult': 1,
        'capacityChild': 0,
        'page': page,
        'limit': 20,
        'keyword': '제주도',
        'checkinDate': '2020-08-16',
        'checkoutDate': '2020-08-17',
        'searchKeyword': '제주도',
        'advert': 'KEYWORD',
        'searchType': 'all',
        'all': 1,
        'sort': 100,
        'themes': None,
        'lat': '37.50681',
        'lng': '127.06624',
        'capacityChildAges': None  
    }

    headers = {
        'Referer' : 'https://www.yanolja.com/search/{0}?placeListType=search&keyword={0}'.format(urllib.parse.quote('제주도')),
        'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36',
        'X-Requested-With': 'XMLHttpRequest',
        'Accept': 'application/json, text/plain, */*',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    #     'Cookie': 'ACEUCI=1; %2Fsearch%2F%EC%A0%9C%EC%A3%BC%EB%8F%84%2Fkeyword-all={%22keyword%22:%22%EC%A0%9C%EC%A3%BC%EB%8F%84%22%2C%22searchKeyword%22:%22%EC%A0%9C%EC%A3%BC%EB%8F%84%22%2C%22checkinDate%22:%222020-08-16%22%2C%22checkoutDate%22:%222020-08-17%22%2C%22capacityAdult%22:1%2C%22capacityChild%22:0%2C%22capacityChildAges%22:%22%22}; cgntId=ap-northeast-2%3A2b47caae-3694-44f0-9d2b-43c98b30c098; yanolja_sid=s%3A0K-pijLPMujuW6NI5cJVcGOYBO2FXY0h.ZwiC623ThkJsrpFM9m7MiLj%2F8qYFHr3272Xla0K8NCk; SavedFiltersKey=/search/%EC%A0%9C%EC%A3%BC%EB%8F%84/keyword-all; ACEUACS=1596521299174217533; ACEFCID=UID-5F28FB542D0B4D05779333B5; _fbp=fb.1.1596521300441.1991528559; _ga=GA1.2.1408952294.1596521300; _gid=GA1.2.788840749.1596521300; location={%22latitude%22:%2237.50681%22%2C%22longitude%22:%22127.06624%22%2C%22address%22:%22%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EA%B0%95%EB%82%A8%EA%B5%AC%20%ED%85%8C%ED%97%A4%EB%9E%80%EB%A1%9C108%EA%B8%B8%2042%22%2C%22addressShort%22:%22%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EA%B0%95%EB%82%A8%EA%B5%AC%20%ED%85%8C%ED%97%A4%EB%9E%80%EB%A1%9C108%EA%B8%B8%22%2C%22addressOnlyRoad%22:%22%ED%85%8C%ED%97%A4%EB%9E%80%EB%A1%9C108%EA%B8%B8%22}; wcs_bt=ae93a192ec48a4:1596521393; AWSALB=zm/Jfq0CVy83/Q/bcMcY2ADivgyVdh6KNQc6bG1tPs9SA7T5733p2wvOClRpxNMSodWkruizJEGIcJbThOG1sBYm+WURo+8cqojOGppWN4ykkwQMNbQuiwexg5Nx; AWSALBCORS=zm/Jfq0CVy83/Q/bcMcY2ADivgyVdh6KNQc6bG1tPs9SA7T5733p2wvOClRpxNMSodWkruizJEGIcJbThOG1sBYm+WURo+8cqojOGppWN4ykkwQMNbQuiwexg5Nx'
    }

    ## 호텔리스트가 홈페이지랑 다르게 나옴 -> 쿠키가 계속 갱신되는 것을 방지하기 위해 -> 처음 홈페이지에 들어가자마자의 쿠키를 저장해놓는다.
    s = requests.Session()
    s.get("https://www.yanolja.com/search/{0}?placeListType=search&keyword={0}".format('제주도'))
    resp = s.get(base_url, params=params, headers=headers)
    # resp = requests.get(base_url, params = params, headers=headers)
    
    
    item_li = json.loads(resp.text)
    
    item_list = []
    #name_list = []
    #score_list = []
    #price_list = []


    for i in range(20):

        # 호텔 이름

        name = item_li['motels']['lists'][i]['name']
        #name_list.append(name)
    #print(name_list)



        # 호텔 점수

        score = item_li['motels']['lists'][i]['reviewScore']
        #score_list.append(score)
    #print(score_list)



        # 리뷰 개수

        count = item_li['motels']['lists'][i]['reviewCounts']
        #count_list.append(count)
    #print(count_list)



        # 호텔 가격 = > 예약마감이면 예약마감이 뜬다.

        if len(item_li['motels']['lists'][i]['displayPrices']) == 1:
            if item_li['motels']['lists'][i]['displayPrices'][0]['priceNote'] == '예약마감':
                price = '예약마감'
                #price_list.append(price)

            else:
                price = item_li['motels']['lists'][i]['displayPrices'][0]['rawDiscountPrice']
                #price_list.append(price)

        elif len(item_li['motels']['lists'][i]['displayPrices']) >= 2:
            for j in range(2):
                if item_li['motels']['lists'][i]['displayPrices'][j]['badgeText'] == '숙박특가':
                    if item_li['motels']['lists'][i]['displayPrices'][j]['priceNote'] == '예약마감':
                        price = '예약마감'
                        #price_list.append(price)

                    else:
                        price = item_li['motels']['lists'][i]['displayPrices'][j]['rawDiscountPrice']
                        #price_list.append(price)
    #print(price_list)



        item_list.append({'name' : name, 
                          'score' : score,
                          'count' : count,
                          'price' : price})
    print(item_list)

# %%
page_item_list(1)
# Out:
# [{'name': '제주 해피니스펜션 (오션뷰,18.3월신축)', 'score': '4.6', 'count': '149', 'price': 59000}, {'name': '호텔 시리우스 제주', 'score': '4.6', 'count': '680', 'price': '예약마감'}, {'name': '서귀포 수펜션', 'score': '4.8', 'count': '51', 'price': '예약마감'}, {'name': '유탑유블레스호텔 제주함덕', 'score': '4.6', 'count': '469', 'price': 89000}, {'name': 'HY 초이호스텔 제주', 'score': '4.4', 'count': '74', 'price': 40000}, {'name': '호텔 리젠트마린', 'score': '4.6', 'count': '923', 'price': 106400}, {'name': '제주 빈티지1950카페펜션(조식제공)', 'score': '4.8', 'count': '290', 'price': 129000}, {'name': '서귀포 펜션연리', 'score': '5', 'count': '37', 'price': 98000}, {'name': '제주 컬리넌 호텔', 'score': '4.4', 'count': '1212', 'price': 49500}, {'name': '서귀포 라운지하우스제주다펜션', 'score': '5', 'count': '2', 'price': 65000}, {'name': '아트스테이 서귀포 하버', 'score': '4.6', 'count': '2063', 'price': 51000}, {'name': '빠레브 호텔 제주', 'score': '4.5', 'count': '291', 'price': 51030}, {'name': '라마다 프라자 제주', 'score': '4.7', 'count': '177', 'price': 189992}, {'name': '봄그리고가을 호텔&리조트', 'score': '4.6', 'count': '1099', 'price': 73000}, {'name': '제주 29풀빌라', 'score': '4.4', 'count': '9', 'price': 250000}, {'name': '제주 늘하우스 펜션&게스트하우스', 'score': '5', 'count': '1', 'price': 15000}, {'name': '롯데 시티호텔 제주', 'score': '4.8', 'count': '365', 'price': 166610}, {'name': '제주 그래펜션', 'score': '5', 'count': '8', 'price': '예약마감'}, {'name': '제주 허브인휴양펜션', 'score': '5', 'count': '28', 'price': 90600}, {'name': '에코그린 리조트&호텔&풀빌라', 'score': '4.3', 'count': '112', 'price': '예약마감'}]

# %%
page_item_list(2)
# Out:
# [{'name': '제주 엠 리조트', 'score': '4.8', 'count': '27', 'price': 70000}, {'name': '서귀포 오아시스휴양펜션', 'score': '5', 'count': '1', 'price': 70000}, {'name': '제주 369펜션', 'score': '5', 'count': '1', 'price': 100000}, {'name': '제주 해와바다 펜션 & 게스트하우스', 'score': '5', 'count': '6', 'price': 60000}, {'name': '서귀포 탐라도다펜션(MD추천)', 'score': '4.9', 'count': '202', 'price': 65000}, {'name': '골든튤립 제주 성산호텔', 'score': '4.4', 'count': '418', 'price': 83100}, {'name': '제주 헤이, 서귀포', 'score': '4.6', 'count': '555', 'price': '예약마감'}, {'name': '서귀포 마가렛펜션(엔틱의상대여)', 'score': '4.6', 'count': '178', 'price': 59000}, {'name': '서귀포 해든빌레펜션', 'score': '4.9', 'count': '32', 'price': 49000}, {'name': '서귀포 더조은하우스펜션', 'score': '4.9', 'count': '51', 'price': 129000}, {'name': '제주 헤이, 서귀포', 'score': '4.7', 'count': '385', 'price': 129000}, {'name': '파크 선샤인 제주', 'score': '4.8', 'count': '383', 'price': 100000}, {'name': '제주 곶자왈거문오름펜션', 'score': '5', 'count': '7', 'price': 70000}, {'name': '제주 이호1820 게스트하우스', 'score': '5', 'count': '2', 'price': 30000}, {'name': '제주 느낌펜션', 'score': '4.6', 'count': '98', 'price': 100800}, {'name': '제주 샤모니리조트', 'score': '4.7', 'count': '84', 'price': 31000}, {'name': '제주 랑데뷰펜션', 'score': '5', 'count': '9', 'price': '예약마감'}, {'name': '제주 하모니리조트', 'score': '5', 'count': '7', 'price': 140000}, {'name': '제주 낭만제주펜션(종달리,MD추천)', 'score': '4.8', 'count': '89', 'price': 60000}, {'name': '서귀포 공천포별장펜션(쇠소깍인근)', 'score': '5', 'count': '8', 'price': 70000}]

# %% [markdown]
# # 나_야놀자

# %%
from bs4 import BeautifulSoup
import requests
import json
import urllib


def page_item_list(page, adult, child, checkin, checkout, keyword):
    base_url = "https://www.yanolja.com/api/v1/contents/search"
    params = {
        'capacityAdult': adult,
        'capacityChild': child,
        'page': page,
        'limit': 20,
        'keyword': keyword,
        'checkinDate': checkin,
        'checkoutDate': checkout,
        'searchKeyword': keyword,
        'advert': 'KEYWORD',
        'searchType': 'all',
        'all': 1,
        'sort': 100,
        'themes': None,
        'lat': '37.50681',
        'lng': '127.06624',
        'capacityChildAges': None  
    }

    headers = {
        'Referer' : 'https://www.yanolja.com/search/{0}?placeListType=search&keyword={0}'.format(urllib.parse.quote(keyword)),
        'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36',
        'X-Requested-With': 'XMLHttpRequest',
        'Accept': 'application/json, text/plain, */*',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    #     'Cookie': 'ACEUCI=1; %2Fsearch%2F%EC%A0%9C%EC%A3%BC%EB%8F%84%2Fkeyword-all={%22keyword%22:%22%EC%A0%9C%EC%A3%BC%EB%8F%84%22%2C%22searchKeyword%22:%22%EC%A0%9C%EC%A3%BC%EB%8F%84%22%2C%22checkinDate%22:%222020-08-16%22%2C%22checkoutDate%22:%222020-08-17%22%2C%22capacityAdult%22:1%2C%22capacityChild%22:0%2C%22capacityChildAges%22:%22%22}; cgntId=ap-northeast-2%3A2b47caae-3694-44f0-9d2b-43c98b30c098; yanolja_sid=s%3A0K-pijLPMujuW6NI5cJVcGOYBO2FXY0h.ZwiC623ThkJsrpFM9m7MiLj%2F8qYFHr3272Xla0K8NCk; SavedFiltersKey=/search/%EC%A0%9C%EC%A3%BC%EB%8F%84/keyword-all; ACEUACS=1596521299174217533; ACEFCID=UID-5F28FB542D0B4D05779333B5; _fbp=fb.1.1596521300441.1991528559; _ga=GA1.2.1408952294.1596521300; _gid=GA1.2.788840749.1596521300; location={%22latitude%22:%2237.50681%22%2C%22longitude%22:%22127.06624%22%2C%22address%22:%22%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EA%B0%95%EB%82%A8%EA%B5%AC%20%ED%85%8C%ED%97%A4%EB%9E%80%EB%A1%9C108%EA%B8%B8%2042%22%2C%22addressShort%22:%22%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EA%B0%95%EB%82%A8%EA%B5%AC%20%ED%85%8C%ED%97%A4%EB%9E%80%EB%A1%9C108%EA%B8%B8%22%2C%22addressOnlyRoad%22:%22%ED%85%8C%ED%97%A4%EB%9E%80%EB%A1%9C108%EA%B8%B8%22}; wcs_bt=ae93a192ec48a4:1596521393; AWSALB=zm/Jfq0CVy83/Q/bcMcY2ADivgyVdh6KNQc6bG1tPs9SA7T5733p2wvOClRpxNMSodWkruizJEGIcJbThOG1sBYm+WURo+8cqojOGppWN4ykkwQMNbQuiwexg5Nx; AWSALBCORS=zm/Jfq0CVy83/Q/bcMcY2ADivgyVdh6KNQc6bG1tPs9SA7T5733p2wvOClRpxNMSodWkruizJEGIcJbThOG1sBYm+WURo+8cqojOGppWN4ykkwQMNbQuiwexg5Nx'
    }

    ## 호텔리스트가 홈페이지랑 다르게 나옴 -> 쿠키가 계속 갱신되는 것을 방지하기 위해 -> 처음 홈페이지에 들어가자마자의 쿠키를 저장해놓는다.
    s = requests.Session()
    s.get("https://www.yanolja.com/search/{0}?placeListType=search&keyword={0}".format(keyword))
    resp = s.get(base_url, params=params, headers=headers)
    # resp = requests.get(base_url, params = params, headers=headers)
    
    
    item_li = json.loads(resp.text)
    
    item_list = []
    #name_list = []
    #score_list = []
    #price_list = []


    for i in range(20):

        # 호텔 이름

        name = item_li['motels']['lists'][i]['name']
        #name_list.append(name)
    #print(name_list)



        # 호텔 점수

        score = item_li['motels']['lists'][i]['reviewScore']
        #score_list.append(score)
    #print(score_list)



        # 리뷰 개수

        count = item_li['motels']['lists'][i]['reviewCounts']
        #count_list.append(count)
    #print(count_list)



        # 호텔 가격 = > 예약마감이면 예약마감이 뜬다.

        if len(item_li['motels']['lists'][i]['displayPrices']) == 1:
            if item_li['motels']['lists'][i]['displayPrices'][0]['priceNote'] == '예약마감':
                price = '예약마감'
                #price_list.append(price)

            else:
                price = item_li['motels']['lists'][i]['displayPrices'][0]['rawDiscountPrice']
                #price_list.append(price)

        elif len(item_li['motels']['lists'][i]['displayPrices']) >= 2:
            for j in range(2):
                if item_li['motels']['lists'][i]['displayPrices'][j]['badgeText'] == '숙박특가':
                    if item_li['motels']['lists'][i]['displayPrices'][j]['priceNote'] == '예약마감':
                        price = '예약마감'
                        #price_list.append(price)

                    else:
                        price = item_li['motels']['lists'][i]['displayPrices'][j]['rawDiscountPrice']
                        #price_list.append(price)
    #print(price_list)



        item_list.append({'name' : name, 
                          'score' : float(score),
                          'count' : float(count),
                          'price' : price})
    print(item_list)

# %%
page_item_list(3, 1, 0, '2020-08-08', '2020-08-09', '속초')
# Out:
# [{'name': '속초 바다스테이펜션', 'score': 4.9, 'count': 23.0, 'price': 212000}, {'name': '고성(속초) 코스트하우스펜션', 'score': 4.6, 'count': 539.0, 'price': 250000}, {'name': '고성(속초) 페블비치펜션', 'score': 4.7, 'count': 364.0, 'price': 210000}, {'name': 'HK리조트', 'score': 4.6, 'count': 96.0, 'price': 100000}, {'name': '속초 호텔 웨이브', 'score': 4.4, 'count': 650.0, 'price': 100000}, {'name': '속초 씨씨펜션', 'score': 4.8, 'count': 75.0, 'price': 219000}, {'name': '속초 등대비치호텔', 'score': 4.6, 'count': 226.0, 'price': 219000}, {'name': '롯데리조트 속초', 'score': 4.9, 'count': 365.0, 'price': '예약마감'}, {'name': '속초 E hotel', 'score': 4.7, 'count': 35.0, 'price': '예약마감'}, {'name': '속초 호텔청초', 'score': 4.4, 'count': 345.0, 'price': '예약마감'}, {'name': '오션투유 리조트 설악비치 호텔앤콘도', 'score': 4.4, 'count': 1064.0, 'price': 229900}, {'name': '양양 속초신원리조트', 'score': 5.0, 'count': 4.0, 'price': 199000}, {'name': '속초 바다향기펜션', 'score': 4.6, 'count': 100.0, 'price': 189000}, {'name': '속초 초원리조텔', 'score': 4.9, 'count': 10.0, 'price': 120000}, {'name': '속초 산토리니펜션(오션뷰,MD추천)', 'score': 4.9, 'count': 104.0, 'price': 189000}, {'name': '속초 (구)해변펜션', 'score': 5.0, 'count': 46.0, 'price': 150000}, {'name': '속초 메모리즈', 'score': 4.7, 'count': 66.0, 'price': 150000}, {'name': '속초 꿈설악펜션(조식무료제공)', 'score': 4.9, 'count': 165.0, 'price': '예약마감'}, {'name': '속초 프리모', 'score': 4.8, 'count': 80.0, 'price': '예약마감'}, {'name': '속초 월드펜션', 'score': 4.6, 'count': 15.0, 'price': 220000}]

# %% [markdown]
# # 유진_호텔스닷컴

# %%
from bs4 import BeautifulSoup
import requests
import json
import urllib


def page_item_list(page, keyword, checkin, checkout, adult, child):
    base_url='https://kr.hotels.com/search/listings.json'
    params={
        #'pg-offset':page,
        #'distination-id':'1644457', 
        'q-check-out': checkin,
        'q-destination':keyword,
        'q-check-in':checkin,
        'q-check-out':checkout,
        'q-rooms':1,
        'q-room-0-adults':adult,
        'q-room-0-children':child,
        'pg':1,
        #'start-index':1,
        'pn':page,
        #'resolved-location':'REGION:1644457:UNKNOWN:UNKNOWN'
    }

    headers={
        'content-type': 'application/javascript',
        'x-requested-with': 'XMLHttpRequest',
        #'referer':'https://kr.hotels.com/search.do?resolved-location=REGION%3A1644457%3AUNKNOWN%3AUNKNOWN&destination-id=1644457&q-destination={0}&q-check-in=2020-08-16&q-check-out=2020-08-17&q-rooms=1&q-room-0-adults=1&q-room-0-children=0'.format(urllib.parse.quote(keyword)),
        'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36',
        'cookie': "asc=1; homepage_search_data=7KCc7KO864-ELCDsoJzso7zsi5wsIO2VnOq1rQ..%2F%2F2020%2F08%2F16%2F%2F2020%2F08%2F17%2F%2F1%2F%2Fyyyy%2FMM%2Fdd%2F%2F1644457%2F%2F; guid=8c8ca612-b270-42cb-95aa-6232c2538458; user=QSprb19LUnxIQ09NX0tS; dr=AAA~1596523818~5C85BBDD535AE5EBF43E87FBF3ED905266EB65950AFBFD78AC0671363A77CA79; akacd_pr_20=1601707820~rv=31~id=44ca8f82368ff8df2ac1cef34c3ccc77; bm_sz=91F45291ECCBD9CF669AE98B49CA6C7D~YAAQa3pGaFBIOoBzAQAALzY8uAjOZf4bEil+pJ9j7T4xHGo5L0We9RrvFkah4Ntqo/cwcLTTJE/iBUXVgkfqE0iJKW9BFb7MP7TecuUec4RqjpNsP2kaEjHxE5mKNYefWc2HoK06cqN5xm/nP7KJBfW4ANgO3yTiCM6bebnDHYkGER21/OCeV4M8NejdwiHs; _ga=GA1.2.20859871.1596523819; _gid=GA1.2.1549673115.1596523819; s_ecid=MCMID%7C78976063976117546201547030336521815933; AMCVS_C00802BE5330A8350A490D4C%40AdobeOrg=1; mvthistory=eJxNj0kKQjEQRG8U0lN62LoRRAQv4PrfwcPb%2Bd2Kq7w8qorEbawxx0EQQJaEgap5zmCXsemwgAl8ugQZuKUHQAZOyUjDva3MqidYRWmzt4RZoGoFhr1iCpXXAOd1Spzm3xEko2IIFMQBFUZZNY5i0uBdX8QVg7xo2XFg0O%2BTANIgXOucvKilzupTMHJXeGGBQA%2FCZv1jK6bN3mHqF%2Be%2B27n%2Fvl4e99ft%2BQErFlFN; AMCV_C00802BE5330A8350A490D4C%40AdobeOrg=-1330315163%7CMCIDTS%7C18479%7CMCMID%7C78976063976117546201547030336521815933%7CMCAID%7CNONE%7CMCOPTOUT-1596531019s%7CNONE%7CMCAAMLH-1597128619%7C11%7CMCAAMB-1597128619%7Cj8Odv6LonN4r3an7LhD3WZrU1bUpAkFkkiY1ncBR96t2PTI; s_cc=true; _abck=2ED1A02051B8DEB245303D2079BFA297~0~~-1~-1~-1; _gcl_au=1.1.160751177.1596523820; _fbp=fb.1.1596523820167.896421725; 0e16e784-167b-49ee-b1ac-0ff7866eb4fbfaktorId=5cac8980-8e5b-4cc8-82d6-c10efc3d3428; lastConsentChange=1596523820269; 0e16e784-167b-49ee-b1ac-0ff7866eb4fbeuconsent=BO3mjO6O3mjO6ADABAENDV-AAAAx6ATgAUABoAEAAKwAXABkAEAAMgAaQBEAEUAI4ATAAngBbAEEAJAATgBCACpAHVARqA; 0e16e784-167b-49ee-b1ac-0ff7866eb4fbcconsent=BO3mjO6O3mjO6ADABAENA7AAAAAOWAAA; 0e16e784-167b-49ee-b1ac-0ff7866eb4fbfaktorChecksum=-1176279445; __gads=ID=0b734ce775df8ba2-222c1fd2c6c2005b:T=1596523822:S=ALNI_MZhdUG_e5KVdQLyxGd-QTgPh34YZg; xdid=0e1a2a2a-35f6-4831-a4f6-f3389ef1ca7a|1596523822|kr.hotels.com; xdidp=0e1a2a2a-35f6-4831-a4f6-f3389ef1ca7a|1596523822|kr.hotels.com; s_sq=%5B%5BB%5D%5D; visitId=edbcaa2e-4968-4009-ac85-383907b77d5f; SESSID=kmF9C5mRd1F3cSUDGpr_gCaDoZ.sa-6f74c7cf76-x4jn8; Session_Pageviews=6; _uetsid=c6e7370525e12b88d62d48ad3703a7c3; _uetvid=3363ca2720f5a4cef91d6a35a5ae68ab",
        #'pragma': 'no-cache',
        #'cache-control': 'no-cache',
        #'accept': 'application/json, text/javascript, */*; q=0.01',
        #'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
        #'accept-encoding': 'gzip, deflate, br'

    #     'cookie': 'channel=DC; 30dlt=seo.hcom.kr.b2.search.naver.com; guid=70b194a6-7d06-4407-813d-439ddc81e8b1; user=QSprb19LUnxIQ09NX0tS; akacd_pr_20=1601370854~rv=10~id=56b99db0bffa807a7ae68b57c1f84d62; _ga=GA1.2.262126391.1596186854; s_ecid=MCMID%7C18020916849438730392200037473831731739; _fbp=fb.1.1596186855014.1096204561; _gcl_au=1.1.2093965117.1596186855; __gads=ID=28a1f36c47d1b899:T=1596186855:S=ALNI_MbMfgFuOVpeHde-Lxvoqy6try5X3w; xdid=03a4919c-5c4e-476b-9704-1db0fd86a8cf|1596186857|kr.hotels.com; xdidp=23fa12ed-bf86-42d0-b153-3665d6e271eb|1596186754|expedia.co.kr; lastConsentChange=1596186857180; mvthistory=eJxNj0luRCEMRG%2BEKA942PampSiKlAtk%2Fe%2BQwwe%2B3a2seDyVyxA%2B1pjjYiTYN1GS2T5nSug4dHliQm63QQcdGQnswC2FeES01VnjG7yifDhaYhaYeYFTt7ih8pYIWbek6fEqIXYuRpISDVSYdFU5qWtD9PhiqRj2xcqOi5LfnwS0QaXaZfPiljZrnlNIeoQnqsdSZFFJRZfjsP1jL%2BbD0WHu1%2B9d4feu3%2Bfj6%2FPn4%2FsPA1NT2Q%3D%3D; bm_sz=9BD21E821845D51FA0D9B135BB256B3A~YAAQDXpGaMvdmYZzAQAA7BL3sgjXMidVKi2JZezEhByPD+UlXFPyGWEuydcxo7jaG5deLqOuRULrEn/lhgOo6iEtj0Wad9xJ0uolA4BJwtwL18+2xpptdBd8jS3LfCLmEC2uX/WB2NnK4m4x4mzrUm7mHQGUykHOubX9A0cqY4zyEdtY0AH0PZ63K2zYl6Mi; asc=1; dr=AAA~1596435404~4AF6F0445D3489A1E092F641066F96B93D40B40DDD943022EE1E98D4913A7C2F; _gid=GA1.2.1546820872.1596435403; AMCVS_C00802BE5330A8350A490D4C%40AdobeOrg=1; s_cc=true; _abck=0D541D156BC09BE7D94D3AADD67548B2~0~~-1~-1~-1; homepage_search_data=7KCc7KO864-ELCDsoJzso7zsi5wsIO2VnOq1rQ..%2F%2F2020%2F08%2F16%2F%2F2020%2F08%2F17%2F%2F1%2F%2Fyyyy%2FMM%2Fdd%2F%2F1644457%2F%2F; visitId=9c2e2fae-5554-4ea6-a40b-89f3d70f6305; SESSID=d1zQ1OkaL9VJyQvfYjWcg2o8sR.sa-665cf686c4-7q8g6; s_sq=%5B%5BB%5D%5D; aws=1; _gat=1; AMCV_C00802BE5330A8350A490D4C%40AdobeOrg=-1330315163%7CMCIDTS%7C18478%7CMCMID%7C18020916849438730392200037473831731739%7CMCAAMLH-1596791653%7C11%7CMCAAMB-1597047604%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1596450004s%7CNONE%7CMCAID%7CNONE; Session_Pageviews=14; _uetsid=f42780afb3dcaf6da3acf7261a71a6e4; _uetvid=26e44a5e73df2819b24f5fccdadd9add'
    }
    
    s = requests.Session()
    resp=s.get(base_url,params=params,headers=headers)
    items=json.loads(resp.text)
    
    
    results=items['data']['body']['searchResults']['results']
   
    
    hotels_list=[]

    for i in range(len(results)):
        hotels_names=items['data']['body']['searchResults']['results'][i]['name']
        if ('guestReviews' in items['data']['body']['searchResults']['results'][i])==False:
            hotels_stars='None'
        else:
            hotels_stars=items['data']['body']['searchResults']['results'][i]['guestReviews']['rating']
            hotels_reviews=items['data']['body']['searchResults']['results'][i]['guestReviews']['total']
        if ('soldOut' in items['data']['body']['searchResults']['results'][i])==False:
            hotels_prices=items['data']['body']['searchResults']['results'][i]['ratePlan']['price']['exactCurrent']
        else:
            hotels_prices='SoldOut'

        hotels_list.append({
            'name': hotels_names,
            'price': hotels_prices,
            'count': hotels_reviews,
            'score': hotels_stars
        })
    
    return hotels_list

# %%
page_item_list(1, '제주도', '2020-08-16', '2020-08-17', 1, 0)
# Out:
# [{'name': '호텔 토스카나 (Hotel Toscana)',
#   'price': 582955.0,
#   'count': 543,
#   'score': '9.2'},
#  {'name': '롯데 호텔 제주 (Lotte Hotel Jeju)',
#   'price': 590000.0,
#   'count': 1288,
#   'score': '9.0'},
#  {'name': '베스트 웨스턴 제주 호텔 (Best Western Jeju Hotel)',
#   'price': 63750.0,
#   'count': 1057,
#   'score': '8.4'},
#  {'name': '서머셋제주신화월드 (Somerset Jeju Shinhwa World)',
#   'price': 'SoldOut',
#   'count': 572,
#   'score': '9.2'},
#  {'name': '라마다 제주시티홀 (Ramada Jeju City Hall)',
#   'price': 65097.0,
#   'count': 683,
#   'score': '8.6'},
#  {'name': '호텔 난타 제주 (Hotel Nanta Jeju)',
#   'price': 76909.0,
#   'count': 1365,
#   'score': '9.0'},
#  {'name': '골드원 호텔 & 스위트 (GoldOne Hotel & Suites)',
#   'price': 261818.0,
#   'count': 101,
#   'score': '8.8'},
#  {'name': '휘닉스 제주 섭지 코지 (Phoenix seopjikoji)',
#   'price': 908183.0,
#   'count': 323,
#   'score': '8.0'},
#  {'name': '썬라이즈호텔 성산점 (Sunrise Hotel Sungsan)',
#   'price': 76364.0,
#   'count': 121,
#   'score': '8.2'},
#  {'name': '스타하우스 (Star House)',
#   'price': 32728.0,
#   'count': 121,
#   'score': 'None'},
#  {'name': '메리어트관 제주신화월드 호텔앤리조트 (Marriott Jeju Shinhwa World Hotels & Resorts)',
#   'price': 'SoldOut',
#   'count': 402,
#   'score': '8.8'},
#  {'name': '리코 리조트 (Rico Resort)',
#   'price': 142602.0,
#   'count': 1,
#   'score': '10.0'},
#  {'name': '호텔 윈 스카이 (Win Sky Hotel)',
#   'price': 39545.0,
#   'count': 186,
#   'score': '8.6'},
#  {'name': '신신호텔 천지연 (Shin Shin Hotel Cheonjiyeon)',
#   'price': 43182.0,
#   'count': 186,
#   'score': 'None'}]

# %% [markdown]
# # 이정환_에어비앤비

# %%
from bs4 import BeautifulSoup
import requests
import json
import urllib


def airbnb(keyword, checkin, checkout, page):  #place = 장소, checkin = 체크인 날짜, checkout :체크아웃 날짜, pages=검색하고자 하는 페이지 수
    
    
    result_list=[]  #크롤링 최종 결과를 담을 리스트
    
    #에어비앤비는 offset이 20단위로 페이지가 변화 ex)offset 0 : 1페이지 , offset 1~20: 2페이지 
    for page in range(1,page+1): #입력받은 페이지 수만큼 모두 크롤링 하기 위해
        if page==1:  #page가 1이면 offset=0
            offset=0
        else:
            offset=page*20  #1보다 크면 page*20
    
    
        #리퀘스트할 url과 파라미터 설정
        base_url="https://www.airbnb.co.kr/s/%EC%A0%9C%EC%A3%BC%EB%8F%84/homes" 
        params={'query': keyword,
         'federated_search_session_id': 'e296e38b-6ec1-4296-9a81-f762cfb2c92a',
         'source': 'structured_search_input_header',
         'search_type': 'pagination',
         'tab_id': 'home_tab',
         'checkin': checkin,
         'refinement_paths[]': '/homes',
         'checkout': checkout,
         'place_id': 'ChIJRUDITFTjDDURMb8emNI2vGY',
         'section_offset': '2',
         'items_offset': offset}
        
        resp=requests.get(base_url,params=params)
        soup=BeautifulSoup(resp.text)
        item_tags=soup.select("#FMP-target > div > div > div > div")
        len(item_tags[0])

        
        #해당 숙소에 대한 상세페이지 url을 가져옴
        a_tags=item_tags[0].find_all("a")
        url_list=[]
        for i in a_tags:
            url_list.append("https://www.airbnb.co.kr%s" %i.get("href"))


        #숙소들의 가격정보를 가져옴
        price_tags=item_tags[0].find_all("span", class_="_1p7iugi")
        price_list=[]
        for i in price_tags:
            try:
                price=i.text.split(":")[2]
            except:
                price=i.text.split(":")[1]

            price_list.append(price.replace("₩",""))

        #숙소들의 리뷰 개수를 가져옴
        count_reviews=item_tags[0].find_all("span",class_="_krjbj")
        count_reviews
        count_reviews_list=[]
        for i in count_reviews:
            if "후기" in str(i):
                count_reviews_list.append(i.text.split(" ")[1])

        #숙소들의 이름과 평점을 가져옴
        name_tags=item_tags[0].find_all("div",class_="_1c2n35az")
        rate_tags=item_tags[0].find_all("span",class_="_10fy1f8")
        
        result=[]
        
        #앞에서 추출한 정보들을 딕셔너리화 하여 result 리스트에 추가
        for n,r,u,p,c in zip(name_tags,rate_tags,url_list,price_list,count_reviews_list):
            result.append({
                "name":n.text,
                "score":r.text,
                "count" :c,
                "price":p,
                "url":u
            })
        for item in result:
            if item["name"] not in result_list:
                result_list.append(item)

                
                
    #최저 가격 숙소 / 최고 평점 숙소 구하기            
    min_price=1000000
    name_of_min_price=""
    min_url=""
    
    highest_rate=0.00
    name_of_hr=""
    highest_url=""
    
    for item in result_list:
        price=item["price"]
        price=price.replace("₩","")
        price=int(price.replace(",",""))

        if price<min_price:
            min_price=price
            name_of_min_price=item["name"]
            min_url=item["url"]
            
        rate=float(item["score"])
        if rate>highest_rate:
            highest_rate=rate
            name_of_hr=item["name"]
            highest_url=item["url"]


    return result_list,"최저 가격 숙소 : %s (가격 : %d), (url : %s )" %(name_of_min_price,min_price,min_url),"최고 평점 숙소 : %s (평점 : %.2f), (url : %s)" %(name_of_hr,highest_rate,highest_url)

# %%
airbnb('제주도', '2020-08-16', '2020-08-17', 1)
# Out:
# ([{'name': '푸르다오션,복층커플룸A(오션뷰)',
#    'score': '4.78',
#    'count': '261개',
#    'price': '102,821',
#    'url': 'https://www.airbnb.co.kr/rooms/17127178?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '몽돌하우스',
#    'score': '4.84',
#    'count': '63개',
#    'price': '34,543',
#    'url': 'https://www.airbnb.co.kr/rooms/15321610?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '법환동 바닷가집 별채',
#    'score': '4.86',
#    'count': '36개',
#    'price': '51,988',
#    'url': 'https://www.airbnb.co.kr/rooms/36090662?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '걷기 좋은 동네 게스트하우스',
#    'score': '4.61',
#    'count': '70개',
#    'price': '35,814',
#    'url': 'https://www.airbnb.co.kr/rooms/18103390?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '가장 합리적인 제주 여행자를 위한 숙소.Cornerstone Hotel 스탠다드 더블',
#    'score': '4.30',
#    'count': '10개',
#    'price': '57,765',
#    'url': 'https://www.airbnb.co.kr/rooms/43834942?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '[플레이스캠프제주] Standard',
#    'score': '4.47',
#    'count': '704개',
#    'price': '53,100',
#    'url': 'https://www.airbnb.co.kr/rooms/19724369?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '불특정식당(손님전용민박)#1',
#    'score': '4.63',
#    'count': '188개',
#    'price': '34,659',
#    'url': 'https://www.airbnb.co.kr/rooms/16491566?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '애월 타운하우스 1층 전체 사용! 넓은 정원! 화장실 2개! 4명까지 가능!',
#    'score': '4.85',
#    'count': '13개',
#    'price': '34,659',
#    'url': 'https://www.airbnb.co.kr/rooms/44255699?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '제주공항 엔틱 1인실 BARN64_vintage blue',
#    'score': '4.37',
#    'count': '161개',
#    'price': '40,435',
#    'url': 'https://www.airbnb.co.kr/rooms/43167592?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '디럭스 트윈 더블',
#    'score': '5.0',
#    'count': '4개',
#    'price': '43,900',
#    'url': 'https://www.airbnb.co.kr/rooms/41779774?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': 'Emily house',
#    'score': '4.67',
#    'count': '3개',
#    'price': '144,412',
#    'url': 'https://www.airbnb.co.kr/rooms/43659982?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '<한나의 집 #1> 여성전용 #제주시청 1.5km #조식제공 #아늑함 #편안함',
#    'score': '4.70',
#    'count': '23개',
#    'price': '27,727',
#    'url': 'https://www.airbnb.co.kr/rooms/43936707?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '제주동부 예쁜집 제주 수스테이 301호 펜트하우스',
#    'score': '4.70',
#    'count': '76개',
#    'price': '63,033',
#    'url': 'https://www.airbnb.co.kr/rooms/44121718?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': "(여성도미토리)100평의 마당과 바다가 이어지는 그림같은 전원주택 '아는언니집'",
#    'score': '3.67',
#    'count': '9개',
#    'price': '27,727',
#    'url': 'https://www.airbnb.co.kr/rooms/32805801?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '에어비앤비 오픈기념  2인실 특가, 전 객실 세탁기, 전자레인지, 큰 냉장고 보유!!',
#    'score': '4.63',
#    'count': '8개',
#    'price': '67,281',
#    'url': 'https://www.airbnb.co.kr/rooms/41780925?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '1싱글족과 젊은 커플들 대환영합니다. 가심비가 뛰어난 작지만 강한 공항주변숙소',
#    'score': '4.71',
#    'count': '57개',
#    'price': '36,310',
#    'url': 'https://www.airbnb.co.kr/rooms/41917060?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': "함덕해수욕장 근처 바다 앞 제주스런 커플동 ‘신흥부부 청보리동'",
#    'score': '4.75',
#    'count': '44개',
#    'price': '92,423',
#    'url': 'https://www.airbnb.co.kr/rooms/43409657?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'},
#   {'name': '제주 서쪽 조용한 마을 속 아늑한 감성 게스트하우스(1인실)-활엽수',
#    'score': '4.82',
#    'count': '85개',
#    'price': '39,280',
#    'url': 'https://www.airbnb.co.kr/rooms/7894631?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30'}],
#  '최저 가격 숙소 : <한나의 집 #1> 여성전용 #제주시청 1.5km #조식제공 #아늑함 #편안함 (가격 : 27727), (url : https://www.airbnb.co.kr/rooms/43936707?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30 )',
#  '최고 평점 숙소 : 디럭스 트윈 더블 (평점 : 5.00), (url : https://www.airbnb.co.kr/rooms/41779774?location=%EC%A0%9C%EC%A3%BC%EB%8F%84&check_in=2020-08-16&check_out=2020-08-17&previous_page_section_name=1000&federated_search_id=f45102d5-4d74-4a82-b5d0-e5cf5a52ec30)')

# %% [markdown]
# # 채송화_부킹닷컴

# %%
from bs4 import BeautifulSoup
import requests
import json
import urllib


def hotel_search(pages,region,checkin,checkout, adult, child):
    base_url='https://www.booking.com/searchresults.ko.html'
    total=[]
    for i in range(pages):
        params={
            'top_ufis':1,
            'rows':25,
            'group_adults':adult,
            'group_children':child,
            'label_click':'undef',
            'checkin_month':checkin.split("-")[1],
            'checkin_monthday':checkin.split("-")[2],
            'checkin_year':checkin.split("-")[0],
            'checkout_month':checkout.split("-")[1],
            'checkout_monthday':checkout.split("-")[2],
            'checkout_year':checkout.split("-")[0],
            'no_rooms':1,
            'raw_dest_type':'region',
            'offset':25*i,   
            'sb_price_type': 'total',
            'ss': region,
            'src_elem': 'sb', 
            'ss_all':0,
            'ssb': 'empty',
            'dest_type': 'region',
            #'search_pageview_id': 'b78a37b8196a0080'
            'search_selected':1
        }
        headers = {
            'Referer': 'https://www.booking.com/searchresults.ko.html',
            'Cookie': 'cors_js=1; _gcl_au=1.1.1758010469.1596413772; bs=%7B%22sr_country_or_region_page%22%3A%22region%22%7D; _ga=GA1.2.882061434.1596413773; _gid=GA1.2.1846610763.1596413773; BJS=-; zz_cook_tms_seg1=1; zz_cook_tms_ep=1; zz_cook_tms_seg3=7; _scid=dff99b5d-2e14-4af2-9550-58237e3d9d4c; _pxvid=8ac1c871-d51e-11ea-b163-0242ac120009; _sctr=1|1596380400000; _pin_unauth=dWlkPU9UazVabVF4T1RRdE56bGhPQzAwTUdabUxXSm1ORFF0WldRMVptVmpNemRrWXpVdw; has_preloaded=1; zz_cook_tms_hlist=3317637; g_state={"i_p":1596531334237,"i_l":2}; utag_main=v_id:0173b1ad0651001df4a85a0a77f203073044706b00bd0$_sn:1$_ss:0$_st:1596448493168$4split:2$4split2:1$ses_id:1596413773394%3Bexp-session$_pn:16%3Bexp-session; _uetsid=f2d8e4c9c62246a0bed0af7e885f8c9f; _uetvid=269cfd473b2529680b9b538f1b46fbc1; bkng=11UmFuZG9tSVYkc2RlIyh9Yaa29%2F3xUOLbXpFeYC4TUhBdXo35xAS%2BPyXteEmAF00C7ntv3OHZGFN5Omw3tnwU%2F3rlk1nbz%2BONusrZE%2BcQgZLBk0JeBSBtWgSf%2BJ%2BC2ShbUfWTKv6cwfj%2FUbmattwzhSpTIYyiyIWa7e5d6rxwuVVQqabr7YAgMkH%2F%2Fu6fNsyuyQoTASDGyEw%3D; _px3=534b016a13eceb8dfd91bad5c3807ed4049eeef67f96ffa26e4b9b0710069380:RhcCPVe8GBdA9jMG9PvURiL0ylPlLetN980mHJcuwmC2w9omcccJP2dnTAIXjLyb5eVJcGGTsFBxUVGdCNCg6g==:1000:sGlUhQDbcD++cAinRcf8FQIrgXsopgDXZYkK7uRiQhuAUhE1XXniOrLt6s/Gb1GMVWTdokUn2mREYh+JnCAJ6PpWZsrVHgWYSaF8wEucBT9rs5PjjXKHUrT7Y6DZV/P832v9mal2qz9asNi/uf7Gt9o/kTvyVoqN90YhP8ivD2M=; _pxde=8e07b07f8b1c1d5d950a0e87a21708a96b04456fe969788c88d7c52548705a1e:eyJ0aW1lc3RhbXAiOjE1OTY0NDY3NjkxMjMsImZfa2IiOjAsImlwY19pZCI6W119; lastSeen=0',
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'    }
        resp=requests.get(base_url,params=params, headers=headers)
        soup=BeautifulSoup(resp.text)

    #     hotellist_inner=soup.find('div',id='hotellist_inner')
    #     hotels=hotellist_inner.find_all('div', class_='sr_item')
        hotels = soup.find_all('div', class_='sr_item')

        hotel_list=[]
        for hotel in hotels:        
            names=hotel.find('span',class_='sr-hotel__name')
            name=names.text#호텔이름
            reviews=hotel.find('div',class_='bui-review-score__badge')
            if reviews:
                review=reviews.text
            else:
                review= None
            costs=hotel.find('div',class_='bui-price-display__value')
            cost=costs.text

            counts=hotel.find('div',class_='bui-review-score__text')
            if counts:
                count = counts.text
            else:
                count = 0
            hotel_list.append({
                'name':name,
                'score':review,
                'price':cost,
                'count':count
            })
        total.extend(hotel_list)
        
     #데이터 잔처리,중복제거   
    for i in total:
        i['name']=i['name'].replace("\n","").strip()
        if i['score']!=None:
            i['score']=i['score'].strip()
            i['score']=float(i['score'])
        i['price']=i['price'].replace("\n","").strip()
        i['price']=i['price'].replace("₩","").strip()
        if i['count']!=0:
            i['count']=i['count'].strip()
            a=i['count'].index('개')
            count_str = i['count'][0:a]
            count_str = count_str.replace(',', '')
            i['count']=int(count_str)
        i['price']=i['price'].replace(',','')
        i['price']=int(i['price'])
        #print(i)
    test=list({s['name']:s for s in total}.values()) 
    return test

# %%
hotel_search(1, '제주도', '2020-08-16', '2020-08-17', 1, 0)
# Out:
# [{'name': '제주 마레보 비치 호텔', 'score': 8.3, 'price': 208800, 'count': 637},
#  {'name': '중문시티호텔', 'score': 7.8, 'price': 37410, 'count': 444},
#  {'name': '케니 스토리 인', 'score': 8.3, 'price': 35100, 'count': 1527},
#  {'name': '데이즈호텔 제주 서귀포', 'score': 8.0, 'price': 54000, 'count': 2049},
#  {'name': '파인힐호텔', 'score': 8.0, 'price': 38700, 'count': 406},
#  {'name': '코업시티호텔 성산', 'score': 8.2, 'price': 43900, 'count': 1787},
#  {'name': '아트스테이 서귀포 하버', 'score': 8.5, 'price': 54600, 'count': 2125},
#  {'name': '제주 뉴오션 리조트', 'score': 7.5, 'price': 63000, 'count': 75},
#  {'name': '라마다 앙코르 서귀포 호텔', 'score': 7.8, 'price': 40500, 'count': 2169},
#  {'name': '블루 하와이 호텔', 'score': 7.8, 'price': 55000, 'count': 248},
#  {'name': '미몽', 'score': 9.3, 'price': 31000, 'count': 254},
#  {'name': '해나 게스트하우스', 'score': 9.2, 'price': 23000, 'count': 53},
#  {'name': '더 베스트 제주 성산', 'score': 8.3, 'price': 86007, 'count': 3025},
#  {'name': '제주 해호텔', 'score': 7.9, 'price': 36000, 'count': 529},
#  {'name': '호텔 알레그리아 서귀포', 'score': 8.0, 'price': 37840, 'count': 783},
#  {'name': '성산 전망좋은 게스트하우스', 'score': 9.3, 'price': 20000, 'count': 346},
#  {'name': '체이슨 호텔 더 리드', 'score': 9.1, 'price': 44550, 'count': 801},
#  {'name': '스카이리더스 호텔', 'score': 7.2, 'price': 32400, 'count': 518},
#  {'name': '라마다 제주시티호텔', 'score': 8.2, 'price': 62100, 'count': 2389},
#  {'name': '화이트드림 펜션', 'score': 7.4, 'price': 60000, 'count': 223},
#  {'name': '제주 수 펜션', 'score': 9.0, 'price': 58800, 'count': 261},
#  {'name': '바다와 자전거', 'score': 8.9, 'price': 23000, 'count': 217},
#  {'name': '빨간풍차펜션', 'score': 8.0, 'price': 36000, 'count': 459},
#  {'name': '아이진 호텔', 'score': 8.6, 'price': 60800, 'count': 1077},
#  {'name': '백패커스홈', 'score': 9.1, 'price': 18000, 'count': 398},
#  {'name': '제주 노블레스 관광호텔', 'score': 8.0, 'price': 49500, 'count': 754}]

# %% [markdown]
# # 모두 합치기
